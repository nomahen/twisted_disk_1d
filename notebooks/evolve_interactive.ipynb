# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
# %matplotlib inline

# %% [markdown]
# ## From Nixon & King 2012
# ### $\partial_t\vec{L} =\,...$

# %% [markdown]
# ### term 1: $...\,\frac{1}{r}\partial_r\left\{\frac{\partial_r\left[\nu_1\Sigma r^3(-\Omega')\right]}{\Sigma\partial_r(r^2\Omega)}\vec{L}\right\} = \frac{3}{r}\partial_r\left\{\frac{r}{|\vec{L}|}\partial_r\left[\nu_1|\vec{L}|\right]\vec{L}\right\}$

# %% [markdown]
# ### term 2: $...\,+\,\frac{1}{r}\partial_r\left[\frac{1}{2}\nu_2r|\vec{L}|\partial_r\vec{l}\right]$

# %% [markdown]
# ### term 3: $...\,+\,\frac{1}{r}\partial_r\left\{\left[\frac{\frac{1}{2}\nu_2r^3\Omega|\partial_r\vec{l}|^2}{\partial_r(r^2\Omega)} + \nu_1(\frac{r\Omega'}{\Omega})\right]\vec{L}\right\} = \frac{1}{r}\partial_r\left\{\left[\nu_2r^2(\partial_r\vec{l})^2 - \frac{3}{2}\nu_1\right]\vec{L}\right\}$

# %% [markdown]
# ### term 4: $...\,+\,\frac{1}{r}\partial_r\left\{\nu_3r\vec{L}\times\partial_r\vec{l}\right\}$

# %% [markdown]
# ### term 5: $...\,+\,\vec{\Omega}_p\times\vec{L}$

# %% [markdown]
# ### And now we want to discretize this, so for convenience, lets just try it term by term....
# ### As follows is the central-difference scheme, but when the advective term dominates (term 3, happens when psi is large), this (I think) becomes unstable

# %% [markdown]
# ### $\vec{L}^{n+1}_i = \vec{L}^n_i + \Delta t(\vec{f}_{1,i} + \vec{f}_{2,i} + \vec{f}_{3,i} + \vec{f}_{4,i} + \vec{f}_{5,i})$

# %% [markdown]
# ### $\vec{f}_{1,i} \approx \frac{3}{4r_i}\frac{1}{\Delta r^2}\left[(r_{i+1} + r_{i})(\vec{l}_{i+1} + \vec{l}_{i})\left(\nu_{1,i+1}|\vec{L}|_{i+1} - \nu_{1,i}|\vec{L}|_{i}\right) - (r_{i} + r_{i-1})(\vec{l}_{i} + \vec{l}_{i-1})\left(\nu_{1,i}|\vec{L}|_{i} - \nu_{1,i-1}|\vec{L}|_{i-1}\right)\right]$

# %% [markdown]
# ### $\vec{f}_{2,i} \approx \frac{1}{16r_i}\frac{1}{\Delta r^2}\left[(\nu_{2,i+1}+\nu_{2,i})(r_{i+1} + r_{i})(|\vec{L}|_{i+1} + |\vec{L}|_{i})(\vec{l}_{i+1} - \vec{l}_{i}) - (\nu_{2,i}+\nu_{2,i-1})(r_{i} + r_{i-1})(|\vec{L}|_{i} + |\vec{L}|_{i-1})(\vec{l}_{i} - \vec{l}_{i-1})\right]$

# %% [markdown]
# ### $\vec{f}_{3,i} \approx \frac{1}{8r_i}\frac{1}{\Delta r^3}\left\{\left[\frac{1}{2}(\nu_{2,i+1} + \nu_{2,i})(r_{i+1} + r_{i})^2(\vec{l}_{i+1}-\vec{l}_{i})^2 - 3(\nu_{1,i+1}+\nu_{1,i})\right](\vec{L}_{i+1}+\vec{L}_{i}) - \left[\frac{1}{2}(\nu_{2,i} + \nu_{2,i-1})(r_{i} + r_{i-1})^2(\vec{l}_{i}-\vec{l}_{i-1})^2 - 3(\nu_{1,i}+\nu_{1,i-1})\right](\vec{L}_{i}+\vec{L}_{i-1})\right\}$

# %% [markdown]
# ### We will write $\vec{f}_{4,i}$ in terms of its $x$, $y$ and $z$ components because of the cross product

# %% [markdown]
# ### $(\vec{f}_{4,i})_x \approx \frac{1}{8r_i}\frac{1}{\Delta r_i^2}\left\{(\nu_{3,i+1}+\nu_{3,i})(r_{i+1}+r_{i})\left[(\vec{L}_{i+1}+\vec{L}_{i})_y(\vec{l}_{i+1}-\vec{l}_{i})_z - (\vec{L}_{i+1}+\vec{L}_{i})_z(\vec{l}_{i+1}-\vec{l}_{i})_y\right] - (\nu_{3,i}+\nu_{3,i-1})(r_{i}+r_{i-1})\left[(\vec{L}_{i}+\vec{L}_{i-1})_y(\vec{l}_{i}-\vec{l}_{i-1})_z - (\vec{L}_{i}+\vec{L}_{i-1})_z(\vec{l}_{i}-\vec{l}_{i-1})_y\right]\right\}$

# %% [markdown]
# ### $(\vec{f}_{4,i})_y \approx \frac{1}{8r_i}\frac{1}{\Delta r_i^2}\left\{(\nu_{3,i+1}+\nu_{3,i})(r_{i+1}+r_{i})\left[(\vec{L}_{i+1}+\vec{L}_{i})_z(\vec{l}_{i+1}-\vec{l}_{i})_x - (\vec{L}_{i+1}+\vec{L}_{i})_x(\vec{l}_{i+1}-\vec{l}_{i})_z\right] - (\nu_{3,i}+\nu_{3,i-1})(r_{i}+r_{i-1})\left[(\vec{L}_{i}+\vec{L}_{i-1})_z(\vec{l}_{i}-\vec{l}_{i-1})_x - (\vec{L}_{i}+\vec{L}_{i-1})_x(\vec{l}_{i}-\vec{l}_{i-1})_z\right]\right\}$

# %% [markdown]
# ### $(\vec{f}_{4,i})_z \approx \frac{1}{8r_i}\frac{1}{\Delta r_i^2}\left\{(\nu_{3,i+1}+\nu_{3,i})(r_{i+1}+r_{i})\left[(\vec{L}_{i+1}+\vec{L}_{i})_x(\vec{l}_{i+1}-\vec{l}_{i})_y - (\vec{L}_{i+1}+\vec{L}_{i})_y(\vec{l}_{i+1}-\vec{l}_{i})_x\right] - (\nu_{3,i}+\nu_{3,i-1})(r_{i}+r_{i-1})\left[(\vec{L}_{i}+\vec{L}_{i-1})_x(\vec{l}_{i}-\vec{l}_{i-1})_y - (\vec{L}_{i}+\vec{L}_{i-1})_y(\vec{l}_{i}-\vec{l}_{i-1})_x\right]\right\}$

# %% [markdown]
# ### $\vec{f}_{5,i} = (\Omega_p)_i(-(\vec{L}_i)_{y}\hat{x} + (\vec{L}_i)_{x}\hat{y})$

# %% [markdown]
# ### Lets declare global constants now

# %%
#########
## User Params

## Physics
H_R = 10**(-3.)#0.015
alpha = 0.2
gamma = 1.0
tilt = 10*(np.pi/180.0)
r0 = 3000.0 # mid point of density distribution
rw = 300.0  # width of density distribution
bhspin = 1.0
dolog = True

## Numerical
cfl = 0.5
tmax = 1 # max runtime of simulation; units of t_viscous
dt_init   = 1e-9  # initial timestep of simulation; units of t_viscous
rmin  = 60.0  # inner radius of disk
rmax  = 6000.0 # outer radius of disk
ngrid = 100 # number of grid points

# %%
# Build Q1, Q2, Q3 functions

def load_Q(path):
    data = open(path,"r")
    parsed = []
    for line in data:
        parsed.append(np.array(line.split()).astype(float))
    return np.array(parsed)[:,0]

Q1_path = "../tables/Q1_1d_a0.2_p0.0_g1.0_np30_ng10000.txt"
Q2_path = "../tables/Q2_1d_a0.2_p0.0_g1.0_np30_ng10000.txt"
Q3_path = "../tables/Q3_1d_a0.2_p0.0_g1.0_np30_ng10000.txt"
Q1_parsed = load_Q(Q1_path)
Q2_parsed = load_Q(Q2_path)
Q3_parsed = load_Q(Q3_path)

s_arr = np.logspace(0,np.log10(11),30) - 1
Q1_func = interp1d(s_arr,np.log10(-Q1_parsed + 1e-30),fill_value='extrapolate')
Q2_func = interp1d(s_arr,np.log10(Q2_parsed + 1e-30),fill_value='extrapolate')
Q3_func = interp1d(s_arr,np.log10(Q3_parsed + 1e-30),fill_value='extrapolate')

# %%
plt.scatter(s_arr,-Q1_parsed)
#plt.yscale('log')
plt.ylim(10**(-5),1)
plt.show()
plt.clf()

dQ1_dpsi_parsed = np.zeros(len(s_arr))
dQ1_dpsi_parsed[1:-1] = (Q1_parsed[2:] - Q1_parsed[:-2])/(s_arr[2:] - s_arr[:-2])
dQ1_dpsi_parsed[0] = dQ1_dpsi_parsed[1]
dQ1_dpsi_parsed[-1] = dQ1_dpsi_parsed[-2]

plt.scatter(s_arr,dQ1_dpsi_parsed)
plt.yscale('log')
plt.ylim(1e-6,1e0)
plt.show()
plt.clf()

# %%
Q1 = -10**(Q1_func(s_arr))
Q2 = 10**(Q2_func(s_arr))
Q3 = 10**(Q3_func(s_arr))

dQ1_dpsi_parsed = np.zeros(len(s_arr))
dQ1_dpsi_parsed[1:-1] = (Q1_parsed[1:-1])

dQ1_dpsi = np.zeros(len(s_arr))
dQ1_dpsi[1:-1] = (Q1[2:] - Q1[:-2])/(s_arr[2:] - s_arr[:-2])
dQ1_dpsi[0] = dQ1_dpsi[1]
dQ1_dpsi[-1] = dQ1_dpsi[-2]

dQ2_dpsi = np.zeros(len(s_arr))
dQ2_dpsi[1:-1] = (Q2[2:] - Q2[:-2])/(s_arr[2:] - s_arr[:-2])
dQ2_dpsi[0] = dQ2_dpsi[1]
dQ2_dpsi[-1] = dQ2_dpsi[-2]


dQ3_dpsi = np.zeros(len(s_arr))
dQ3_dpsi[1:-1] = (Q3[2:] - Q3[:-2])/(s_arr[2:] - s_arr[:-2])
dQ3_dpsi[0] = dQ3_dpsi[1]
dQ3_dpsi[-1] = dQ3_dpsi[-2]


plt.plot(s_arr,Q2)
plt.scatter(s_arr,Q2,color='black',s=4)
plt.show()
plt.clf()
plt.plot(s_arr,dQ2_dpsi)
plt.scatter(s_arr,dQ_dpsi,color='black',s=4)
plt.show()
plt.clf()

# %%
# ## Initializations
# radial quantities
if dolog:
    r = np.logspace(np.log10(rmin),np.log10(rmax),ngrid)
    dr = r[1:-1]*np.log(10)*(np.log10(r)[2:] - np.log10(r)[:-2])
else:
    r = np.linspace(rmin,rmax,ngrid)
    dr = r[2:] - r[:-2]

omega = r**(-3.0/2.0)
#density = np.sin(10.0*2.0*np.pi*radii/100.0) + 1.0
#density = np.ones(ngrid)
density = (1.0/(rw*np.sqrt(2.0*np.pi))) * np.exp(-0.5*((r - r0)/rw)**2.0)
density /= np.average(density)
amom_mag = density * omega * r**2.0

# generate radial profile of angular momentum vectors
amom_unit   = np.array([np.sin(tilt),0.0,np.cos(tilt)])
amom_uvector = np.array([amom_unit]*ngrid)
amom_vector = np.copy(amom_uvector)
for i in range(3): amom_vector[:,i] *= amom_mag
    
# for Lense-Thirring Precession
omega_p = np.zeros(3*ngrid)
omega_p = np.reshape(omega_p,(ngrid,3))
omega_p[:,2] = 2.0 * bhspin / r**3.0 # Black hole spin is in z direction

# calculate viscous time
nu_ref = (-2.0/3.0)*(-1.0*10**(Q1_func(0)))*((H_R**2.0)*r0**0.5)
t_viscous = r0*r0/nu_ref
tmax = tmax*t_viscous
dt_init = dt_init*t_viscous
print "tmax/t_viscous: ", tmax/t_viscous
print "dt_init/t_viscous: ", dt_init/t_viscous
# Out:
# tmax/t_viscous:  1.0
# dt_init/t_viscous:  1e-09

# %%
def evolve():
    # Get initial timestep
    dt = np.copy(dt_init)
    
    # Initialize angular momentum array to initial condition
    L = np.copy(amom_vector)
    
    # Initialize arrays
    psi = np.zeros(len(L))
    Q1  = np.zeros(len(L))
    Q2  = np.zeros(len(L))
    Q3  = np.zeros(len(L))
    nu1 = np.zeros(len(L))
    nu2 = np.zeros(len(L))
    nu3 = np.zeros(len(L))
    prec_old = np.zeros(len(L))
    
    # Initialize time
    t = 0.0
    
    # Initialize output array
    output = []
    ofreq = 0.000001*t_viscous
    output_prefix = "evolve_"
    output_cnt = 0
        
    while (t < tmax):
        
        # initialize derivatives to zero at the beginning of every iteration
        dLxdt = np.zeros(len(L))
        dLydt = np.zeros(len(L))
        dLzdt = np.zeros(len(L))
                
        # we will evolve the cartesian components of the angular momentum vectors
        Lx = L[:,0]
        Ly = L[:,1]
        Lz = L[:,2]
        Lmag = np.sqrt(Lx**2.0 + Ly**2.0 + Lz**2.0)
        
        # now construct the components of the angular momentum unit vectors
        lx = Lx/Lmag
        ly = Ly/Lmag
        lz = Lz/Lmag
        l = np.array(zip(lx,ly,lz))
        
        # calculate warp parameter
        psi_x = (0.5*r[1:-1]/dr)*(l[2:,0]-l[:-2,0])
        psi_y = (0.5*r[1:-1]/dr)*(l[2:,1]-l[:-2,1])
        psi_z = (0.5*r[1:-1]/dr)*(l[2:,2]-l[:-2,2])
        psi[1:-1] = np.sqrt(psi_x**2.0 + psi_y**2.0 + psi_z**2.0)
        psi[0] = psi[1]
        psi[-1] = psi[-2]
        
        # calculate nu1,nu2,nu3
        nu1[1:-1] = (-2.0/3.0)*(-1.0*10**(Q1_func(psi[1:-1])))*((H_R**2.0)*r[1:-1]**0.5)
        nu1[0] = nu1[1]
        nu1[-1] = nu1[-2]

        nu2[1:-1] = 2.0*10**(Q2_func(psi[1:-1]))*((H_R**2.0)*r[1:-1]**0.5)
        nu2[0] = nu2[1]
        nu2[-1] = nu2[-2]

        nu3[1:-1] = 10**(Q3_func(psi[1:-1]))*((H_R**2.0)*r[1:-1]**0.5)
        nu3[0] = nu3[1]
        nu3[-1] = nu3[-2]

        #### Lets begin constructing the terms to evolve Lx, Ly, and Lz
        
        ## f1
        f1_x = (3.0/(4.0*r[1:-1]))*(1.0/dr**2.0)*((r[2:]+r[1:-1])*(l[2:,0]+l[1:-1,0])*(nu1[2:]*Lmag[2:]-nu1[1:-1]*Lmag[1:-1]) - (r[1:-1]+r[:-2])*(l[1:-1,0]+l[:-2,0])*(nu1[1:-1]*Lmag[1:-1]-nu1[:-2]*Lmag[:-2]))
        f1_y = (3.0/(4.0*r[1:-1]))*(1.0/dr**2.0)*((r[2:]+r[1:-1])*(l[2:,1]+l[1:-1,1])*(nu1[2:]*Lmag[2:]-nu1[1:-1]*Lmag[1:-1]) - (r[1:-1]+r[:-2])*(l[1:-1,1]+l[:-2,1])*(nu1[1:-1]*Lmag[1:-1]-nu1[:-2]*Lmag[:-2]))
        f1_z = (3.0/(4.0*r[1:-1]))*(1.0/dr**2.0)*((r[2:]+r[1:-1])*(l[2:,2]+l[1:-1,2])*(nu1[2:]*Lmag[2:]-nu1[1:-1]*Lmag[1:-1]) - (r[1:-1]+r[:-2])*(l[1:-1,2]+l[:-2,2])*(nu1[1:-1]*Lmag[1:-1]-nu1[:-2]*Lmag[:-2]))
        
        ## f2
        f2_x = (1.0/(16.0*r[1:-1]))*(1.0/dr**2.0)*((nu2[2:]+nu2[1:-1])*(r[2:]+r[1:-1])*(Lmag[2:]+Lmag[1:-1])*(l[2:,0]-l[1:-1,0]) - (nu2[1:-1]+nu2[:-2])*(r[1:-1]+r[:-2])*(Lmag[1:-1]+Lmag[:-2])*(l[1:-1,0]-l[:-2,0]))
        f2_y = (1.0/(16.0*r[1:-1]))*(1.0/dr**2.0)*((nu2[2:]+nu2[1:-1])*(r[2:]+r[1:-1])*(Lmag[2:]+Lmag[1:-1])*(l[2:,1]-l[1:-1,1]) - (nu2[1:-1]+nu2[:-2])*(r[1:-1]+r[:-2])*(Lmag[1:-1]+Lmag[:-2])*(l[1:-1,1]-l[:-2,1]))
        f2_z = (1.0/(16.0*r[1:-1]))*(1.0/dr**2.0)*((nu2[2:]+nu2[1:-1])*(r[2:]+r[1:-1])*(Lmag[2:]+Lmag[1:-1])*(l[2:,2]-l[1:-1,2]) - (nu2[1:-1]+nu2[:-2])*(r[1:-1]+r[:-2])*(Lmag[1:-1]+Lmag[:-2])*(l[1:-1,2]-l[:-2,2]))
        
        ## f3
        f3_x = (1.0/(8.0*r[1:-1]))*(1.0/dr**3.0)*((0.5*(nu2[2:]+nu2[1:-1])*((r[2:]+r[1:-1])**2.0)*((l[2:,0]-l[1:-1,0])**2.0 + (l[2:,1]-l[1:-1,1])**2.0 + (l[2:,2]-l[1:-1,2])**2.0) - 3.0*(nu1[2:]+nu1[1:-1]))*(L[2:,0] + L[1:-1,0]) - (0.5*(nu2[1:-1]+nu2[:-2])*((r[1:-1]+r[:-2])**2.0)*((l[1:-1,0]-l[:-2,0])**2.0 + (l[1:-1,1]-l[:-2,1])**2.0 + (l[1:-1,2]-l[:-2,2])**2.0) - 3.0*(nu1[1:-1]+nu1[:-2]))*(L[1:-1,0] + L[:-2,0]))
        f3_y = (1.0/(8.0*r[1:-1]))*(1.0/dr**3.0)*((0.5*(nu2[2:]+nu2[1:-1])*((r[2:]+r[1:-1])**2.0)*((l[2:,0]-l[1:-1,0])**2.0 + (l[2:,1]-l[1:-1,1])**2.0 + (l[2:,2]-l[1:-1,2])**2.0) - 3.0*(nu1[2:]+nu1[1:-1]))*(L[2:,1] + L[1:-1,1]) - (0.5*(nu2[1:-1]+nu2[:-2])*((r[1:-1]+r[:-2])**2.0)*((l[1:-1,0]-l[:-2,0])**2.0 + (l[1:-1,1]-l[:-2,1])**2.0 + (l[1:-1,2]-l[:-2,2])**2.0) - 3.0*(nu1[1:-1]+nu1[:-2]))*(L[1:-1,1] + L[:-2,1]))
        f3_z = (1.0/(8.0*r[1:-1]))*(1.0/dr**3.0)*((0.5*(nu2[2:]+nu2[1:-1])*((r[2:]+r[1:-1])**2.0)*((l[2:,0]-l[1:-1,0])**2.0 + (l[2:,1]-l[1:-1,1])**2.0 + (l[2:,2]-l[1:-1,2])**2.0) - 3.0*(nu1[2:]+nu1[1:-1]))*(L[2:,2] + L[1:-1,2]) - (0.5*(nu2[1:-1]+nu2[:-2])*((r[1:-1]+r[:-2])**2.0)*((l[1:-1,0]-l[:-2,0])**2.0 + (l[1:-1,1]-l[:-2,1])**2.0 + (l[1:-1,2]-l[:-2,2])**2.0) - 3.0*(nu1[1:-1]+nu1[:-2]))*(L[1:-1,2] + L[:-2,2]))
        
        ## f4
        f4_x = (1.0/(8.0*r[1:-1]))*(1.0/dr**2.0)*((nu3[2:]+nu3[1:-1])*(r[2:]+r[1:-1])*((L[2:,1]+L[1:-1,1])*(l[2:,2]-l[1:-1,2]) - (L[2:,2]+L[1:-1,2])*(l[2:,1]-l[1:-1,1])) - (nu3[1:-1]+nu3[:-2])*(r[1:-1]+r[:-2])*((L[1:-1,1]+L[:-2,1])*(l[1:-1,2]-l[:-2,2]) - (L[1:-1,2]+L[:-2,2])*(l[1:-1,1]-l[:-2,1])))
        f4_y = (1.0/(8.0*r[1:-1]))*(1.0/dr**2.0)*((nu3[2:]+nu3[1:-1])*(r[2:]+r[1:-1])*((L[2:,2]+L[1:-1,2])*(l[2:,0]-l[1:-1,0]) - (L[2:,0]+L[1:-1,0])*(l[2:,2]-l[1:-1,2])) - (nu3[1:-1]+nu3[:-2])*(r[1:-1]+r[:-2])*((L[1:-1,2]+L[:-2,2])*(l[1:-1,0]-l[:-2,0]) - (L[1:-1,0]+L[:-2,0])*(l[1:-1,2]-l[:-2,2])))
        f4_z = (1.0/(8.0*r[1:-1]))*(1.0/dr**2.0)*((nu3[2:]+nu3[1:-1])*(r[2:]+r[1:-1])*((L[2:,0]+L[1:-1,0])*(l[2:,1]-l[1:-1,1]) - (L[2:,1]+L[1:-1,1])*(l[2:,0]-l[1:-1,0])) - (nu3[1:-1]+nu3[:-2])*(r[1:-1]+r[:-2])*((L[1:-1,0]+L[:-2,0])*(l[1:-1,1]-l[:-2,1]) - (L[1:-1,1]+L[:-2,1])*(l[1:-1,0]-l[:-2,0])))
        
        ## f5
        f5_x = omega_p[1:-1,2]*(-1.0)*L[1:-1,1]
        f5_y = omega_p[1:-1,2]*L[1:-1,0]
        
        
        #### Save before updates
        if ((t%ofreq < dt)):
            np.savetxt("../outputs/" + output_prefix + str(output_cnt) + ".csv", np.array(zip(Lx,Ly,Lz,r)))
            output_cnt += 1
        
        #### Plot before updates
        if ((t%0.000001*t_viscous < dt) and (1)):
            print "Finishing iteration at time t = %s/t_viscous with timestep %s/t_viscous" % (t/t_viscous,dt/t_viscous)
            print "PSI:", np.max(psi)#,"\n\n"
            surface_density = Lmag / omega / r**2.0
            
            #plt.plot(radii,L)
            tilt = np.arcsin(np.sqrt(lx**2.0 + ly**2.0))*180.0/np.pi
            plt.plot(r,tilt,color='darkblue')
            plt.xlim(np.min(r),np.max(r))            
            plt.ylim(0,11)
            plt.ylabel(r"$T\,[{\rm deg}]$")
            plt.xscale('log')
            plt.show()
            plt.clf()
            prec = np.arctan2(ly,lx)*180.0/np.pi
            pdot = (prec - prec_old)/dt
            plt.plot(r,pdot/360.0/omega_p[:,2][0],color='magenta')
            plt.plot(r,omega_p[:,2]/omega_p[:,2][0],color='black',ls='--',lw=0.8)
            plt.xlim(np.min(r),np.max(r))
            plt.ylim(-2,2)
            plt.ylabel(r"$\dot{P}$")
            plt.xscale('log')
            plt.show()
            plt.clf()
            plt.plot(r,surface_density,color='darkred')
            plt.xlim(np.min(r),np.max(r))
            plt.ylim(0,20)
            plt.ylabel(r"$\rho$")
            plt.xscale('log')
            plt.show()
            plt.clf()
            
        # for Pdot
        prec_old = np.arctan2(ly,lx)*180.0/np.pi
        
        #### Apply updates!
        dLxdt[1:-1] = f1_x + f2_x + f3_x + f4_x + f5_x
        dLydt[1:-1] = f1_y + f2_y + f3_y + f4_y + f5_y
        dLzdt[1:-1] = f1_z + f2_z + f3_z + f4_z
        
        Lx = Lx + dt*dLxdt
        Ly = Ly + dt*dLydt
        Lz = Lz + dt*dLzdt
        
        #### Update timestep
        t += dt
        
        if (1): #### Apply sink boundary conditions
            Lx[0] = 1e-10 * Lx[1]
            Lx[-1] = 1e-10 * Lx[-2]
            Ly[0] = 1e-10 * Ly[1]
            Ly[-1] = 1e-10 * Ly[-2]
            Lz[0] = 1e-10 * Lz[1]
            Lz[-1] = 1e-10 * Lz[-2]
        if (0): #### Apply outflow boundary conditions
            Lx[0] = Lx[1];
            Lx[-1] = Lx[-2];
            Ly[0] = Ly[1];
            Ly[-1] = Ly[-2];
            Lz[0] = Lz[1];
            Lz[-1] = Lz[-2];
        
        #### Repackage array (but why?)
        L = np.array(zip(Lx,Ly,Lz))

# %%
a = [1,2,3]
b = [10,20,30]
c = [100,200,300]
t = np.array(zip(a,b,c))
tx = t[:,0]
ty = t[:,1]
tz = t[:,2]
print t[2:,0] == t[:,0][2:]
print t,tx,ty,tz, '\n'
print tx**2.0 + ty**2.0 + tz**2.0
evolve()
# Out:
# [ True]
# [[  1  10 100]
#  [  2  20 200]
#  [  3  30 300]] [1 2 3] [10 20 30] [100 200 300]
#
# [10101. 40404. 90909.]
# Finishing iteration at time t = 0.0/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.2026421911289274e-15
# Finishing iteration at time t = 6.129999999999997e-07/t_viscous with timestep 1e-09/t_viscous
# PSI: 0.8627320993042333
# Finishing iteration at time t = 1.676000000000016e-06/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.7674857539292683
# Finishing iteration at time t = 1.9359999999999972e-06/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.805999303212104
# Finishing iteration at time t = 2.1959999999999786e-06/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.762355294005924
# Finishing iteration at time t = 4.573000000000381e-06/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.6644353018315077
# Finishing iteration at time t = 5.780000000000255e-06/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.6311092556406739
# Finishing iteration at time t = 6.4170000000000285e-06/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.6223270779849586
# Finishing iteration at time t = 7.321999999999707e-06/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.6038814796440917
# Finishing iteration at time t = 7.958999999999481e-06/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.5939151579142028
# Finishing iteration at time t = 9.500999999998934e-06/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.5661067458674243
# Finishing iteration at time t = 1.1042999999998386e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.538989898023293
# Finishing iteration at time t = 1.258499999999784e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.5179042929730624
# Finishing iteration at time t = 1.3221999999997615e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.5164921971735892
# Finishing iteration at time t = 1.4126999999997293e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.5021279758229267
# Finishing iteration at time t = 1.4763999999997067e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.4965189868895037
# Finishing iteration at time t = 1.5668999999996746e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.4884965690253715
# Finishing iteration at time t = 1.630599999999652e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.474522830146001
# Finishing iteration at time t = 1.7847999999995974e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.465966948171559
# Finishing iteration at time t = 1.9389999999995425e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.4522950088508788
# Finishing iteration at time t = 2.0562999999995012e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.4388300327252406
# Finishing iteration at time t = 2.1199999999994786e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.4314653253006524
# Finishing iteration at time t = 2.2104999999994463e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.4293077218420027
# Finishing iteration at time t = 2.2741999999994237e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.4238547401670973
# Finishing iteration at time t = 2.3646999999993917e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.4104951854382632
# Finishing iteration at time t = 2.428399999999369e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.4089575634583493
# Finishing iteration at time t = 2.5825999999993142e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.4003484614450876
# Finishing iteration at time t = 2.7367999999992596e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.3860890756010182
# Finishing iteration at time t = 2.890999999999205e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.3799227901052984
# Finishing iteration at time t = 2.9546999999991825e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.3740404323308597
# Finishing iteration at time t = 3.0451999999991502e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.362579894789526
# Finishing iteration at time t = 3.108899999999128e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.362765000189925
# Finishing iteration at time t = 3.199399999999095e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.3604482061451963
# Finishing iteration at time t = 3.263099999999073e-05/t_viscous with timestep 1e-09/t_viscous
# PSI: 1.3569928715239374
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-2833d7baeec2> in <module>()
#       9 print t,tx,ty,tz, '\n'
#      10 print tx**2.0 + ty**2.0 + tz**2.0
# ---> 11 evolve()
#
# <ipython-input-9-45b51b3eb2dd> in evolve()
#     120             plt.ylabel(r"$\dot{P}$")
#     121             plt.xscale('log')
# --> 122             plt.show()
#     123             plt.clf()
#     124             plt.plot(r,surface_density,color='darkred')
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# /usr/local/lib/python2.7/dist-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /home/nkaaz/.local/lib/python2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     309             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     310         else:
# --> 311             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     312             if not format_dict:
#     313                 # nothing to display (e.g. _ipython_display_ took over)
#
# /home/nkaaz/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     171             md = None
#     172             try:
# --> 173                 data = formatter(obj)
#     174             except:
#     175                 # FIXME: log the exception
#
# </home/nkaaz/.local/lib/python2.7/site-packages/decorator.pyc:decorator-gen-9> in __call__(self, obj)
#
# /home/nkaaz/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     215     """show traceback on failed format call"""
#     216     try:
# --> 217         r = method(self, *args, **kwargs)
#     218     except NotImplementedError:
#     219         # don't warn on NotImplementedErrors
#
# /home/nkaaz/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /home/nkaaz/.local/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /home/nkaaz/.local/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     129
#     130     bytes_io = BytesIO()
# --> 131     fig.canvas.print_figure(bytes_io, **kw)
#     132     data = bytes_io.getvalue()
#     133     if fmt == 'svg':
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
# -> 2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#    2215
#    2216                 bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/figure.pyc in get_tightbbox(self, renderer)
#    2222         for ax in self.axes:
#    2223             if ax.get_visible():
# -> 2224                 bb.append(ax.get_tightbbox(renderer))
#    2225
#    2226         if len(bb) == 0:
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in get_tightbbox(self, renderer, call_axes_locator)
#    4196             bb.append(self._right_title.get_window_extent(renderer))
#    4197
# -> 4198         bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4199         if bb_xaxis:
#    4200             bb.append(bb_xaxis)
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/axis.pyc in get_tightbbox(self, renderer)
#    1145         ticks_to_draw = self._update_ticks(renderer)
#    1146
# -> 1147         self._update_label_position(renderer)
#    1148
#    1149         # go back to just this axis's tick labels
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/axis.pyc in _update_label_position(self, renderer)
#    1904         # get bounding boxes for this axis and any siblings
#    1905         # that have been set by `fig.align_xlabels()`
# -> 1906         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    1907
#    1908         x, y = self.label.get_position()
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick_boxes_siblings(self, renderer)
#    1888         # if we want to align labels from other axes:
#    1889         for nn, axx in enumerate(grp.get_siblings(self.axes)):
# -> 1890             ticks_to_draw = axx.xaxis._update_ticks(renderer)
#    1891             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    1892             bboxes.extend(tlb)
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/axis.pyc in _update_ticks(self, renderer)
#    1026
#    1027         interval = self.get_view_interval()
# -> 1028         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1029         if self._smart_bounds and tick_tups:
#    1030             # handle inverted limits
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/axis.pyc in iter_ticks(self)
#     975                        for i, val in enumerate(majorLocs)]
#     976
# --> 977         minorLocs = self.minor.locator()
#     978         minorTicks = self.get_minor_ticks(len(minorLocs))
#     979         self.minor.formatter.set_locs(minorLocs)
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/ticker.pyc in __call__(self)
#    2096         'Return the locations of the ticks'
#    2097         vmin, vmax = self.axis.get_view_interval()
# -> 2098         return self.tick_values(vmin, vmax)
#    2099
#    2100     def tick_values(self, vmin, vmax):
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/ticker.pyc in tick_values(self, vmin, vmax)
#    2101         if self.numticks == 'auto':
#    2102             if self.axis is not None:
# -> 2103                 numticks = np.clip(self.axis.get_tick_space(), 2, 9)
#    2104             else:
#    2105                 numticks = 9
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/axis.pyc in get_tick_space(self)
#    2122         ends = self.axes.transAxes.transform([[0, 0], [1, 0]])
#    2123         length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72.0
# -> 2124         tick = self._get_tick(True)
#    2125         # There is a heuristic here that the aspect ratio of tick text
#    2126         # is no more than 3:1
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1790         else:
#    1791             tick_kw = self._minor_tick_kw
# -> 1792         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1793
#    1794     def _get_label(self):
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     175
#     176         self.tick1line = self._get_tick1line()
# --> 177         self.tick2line = self._get_tick2line()
#     178         self.gridline = self._get_gridline()
#     179
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick2line(self)
#     486                           markersize=self._size,
#     487                           markeredgewidth=self._width,
# --> 488                           zorder=self._zorder)
#     489
#     490         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     410         self._markerfacecoloralt = None
#     411
# --> 412         self.set_markerfacecolor(markerfacecolor)
#     413         self.set_markerfacecoloralt(markerfacecoloralt)
#     414         self.set_markeredgecolor(markeredgecolor)
#
# /home/nkaaz/.local/lib/python2.7/site-packages/matplotlib/lines.pyc in set_markerfacecolor(self, fc)
#    1176         if fc is None:
#    1177             fc = 'auto'
# -> 1178         if np.any(self._markerfacecolor != fc):
#    1179             self.stale = True
#    1180         self._markerfacecolor = fc
#
# /home/nkaaz/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in any(a, axis, out, keepdims)
#    2162
#    2163     """
# -> 2164     return _wrapreduction(a, np.logical_or, 'any', axis, None, out, keepdims=keepdims)
#    2165
#    2166
#
# /home/nkaaz/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:
